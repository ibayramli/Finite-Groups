# %%
import sys
import os

from src.euclidean_algo import *

# %% [markdown]
#  ## Euclidean Algorithm Tests

# %%
def test(p, integers):
    for a in test_integers:
        m, n = extend_euclidean(p, a)
        inverse = invert_a_mod_b(p, a)
        gcd_p_a = gcd(p, a)
        print("For p={} and a={}, m is {} while n is {}.".format(p, a, m, n))
        print("Here pm + an equals {}.".format(p*m + a*n)) 
        
        if gcd_p_a != 1:
            print("Multiplicative inverse of a in Z_{} does not exist since {} is not a prime. \n".format(p, p))
            continue

        print("Inverse of {} mod {} is {}.".format(a, p, inverse))
        print("We can check that {} times {} mod {} is {}".format(a, inverse, p, (a*inverse)%p))
        print("\n")
    
    return

# %%
# A Fermat prime
p = 2^13 + 1

test_integers = [2, 5, 10, 20, 50, 67, 129, 278, 3725, 10776]

test(p, test_integers)
# Out:
# For p=12 and a=2, m is 0 while n is 1.
# Here pm + an equals 2.
# Multiplicative inverse of a in Z_12 does not exist since 12 is not a prime.
#
# For p=12 and a=5, m is -2 while n is 5.
# Here pm + an equals 1.
# Inverse of 5 mod 12 is 5.
# We can check that 5 times 5 mod 12 is 1
#
#
# For p=12 and a=10, m is 1 while n is -1.
# Here pm + an equals 2.
# Multiplicative inverse of a in Z_12 does not exist since 12 is not a prime.
#
# For p=12 and a=20, m is 1 while n is 0.
# Here pm + an equals 12.
# Multiplicative inverse of a in Z_12 does not exist since 12 is not a prime.
#
# For p=12 and a=50, m is 1 while n is 0.
# Here pm + an equals 12.
# Multiplicative inverse of a in Z_12 does not exist since 12 is not a prime.
#
# For p=12 and a=67, m is 1 while n is 0.
# Here pm + an equals 12.
# Inverse of 67 mod 12 is 0.
# We can check that 67 times 0 mod 12 is 0
#
#
# For p=12 and a=129, m is 1 while n is 0.
# Here pm + an equals 12.
# ...
